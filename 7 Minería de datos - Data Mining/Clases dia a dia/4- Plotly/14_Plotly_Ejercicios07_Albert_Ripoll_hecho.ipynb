# %%
#Haz un upgrade de la versión de plotly
# !pip install --upgrade plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 48.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %%
#Haz los imports que creas convenientes
import pandas as pd
import plotly.express as px

# %%
#Importa el dataset de la esperanza de vida
df = pd.read_csv('https://raw.githubusercontent.com/4data-lab/datasets/master/life-expectancy.csv')

# %%
#¿Qué tamaño tiene el dataset?
df.shape
# Out:
# (1704, 8)

# %%
#Visualiza las 10 primeras filas del dataset.
df.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360       AFG
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439       AFG
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945       AFG
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395       AFG
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        4
# 6        4
# 7        4
# 8        4
# 9        4

# %%
#¿De qué años hay datos en el dataset?
df["year"].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %% [markdown]
# 1 - Dibuja un "pie" chart con el porcentaje de población por cada continente en el año 1957.

# %%
px.pie(df[df['year']==1957], values="pop", names="continent", title="Pie Chart")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 2- Muestra un sunburst en el que se vean los continentes en el círculo interior y el nombre de países en el círculo exterior.

# %%
sb = px.sunburst(df, path=['continent', 'country'], color='continent', title='Sunburst Chart')
sb.update_layout(autosize=False,width=800,height=800,)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 3- Muestra un treemap en el que se segreguen los continentes y países. El tamaño de cada país debe ser proporcional a su población el año 1957.

# %%
px.treemap(df[df['year']==1957], path=['continent','country'],values='pop')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 4- Muestra una animación en la que se vea cómo cambia la población de cada país a lo largo de los años en un gráfico de barras. Pinta los países de un mismo continente de un color identificativo.
#
# Ajusta los ejes convenientemente.

# %%
px.bar(df, x='country', y='pop', color='continent', hover_name='country',animation_frame="year", animation_group="country",range_y=[0,1400000000])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 5- En el ejercicio anterior habrás observado que hay dos países que tienen una población muy superior a la anterior. Haz la misma animación pero excluyendo esos países y re-ajustando los ejes.

# %%
sin_india = df[df['country']!="India"]
sin_china = sin_india[sin_india['country']!="China"]
#df.drop(5)
px.bar(sin_china, x='country', y='pop', color='continent', hover_name='country',animation_frame="year", animation_group="country",range_y=[0,310000000])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Importa el dataset de Pokemon
df = pd.read_csv('https://raw.githubusercontent.com/4data-lab/datasets/master/pokemon.csv')

# %%
#Muestra las cinco últimas instancias del dataset
df.tail()
# Out:
#           Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 146    Dratini   Dragon     NaN    300   41      64       45       50
# 147  Dragonair   Dragon     NaN    420   61      84       65       70
# 148  Dragonite   Dragon  Flying    600   91     134       95      100
# 149     Mewtwo  Psychic     NaN    680  106     110       90      154
# 150        Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 146       50     50      1      False
# 147       70     70      2      False
# 148      100     80      3      False
# 149       90    130      1       True
# 150      100    100      1      False

# %% [markdown]
# 6- Muestra un gráfico de barras en el que se vean tantas barras como tipos pokemons hay, tan largas como ataques tenga esa clase (barras segregadas por pokemon) y de tres colores distintos dependiendo de su Stage.
# Como solamente hay tres stages, la leyenda debería tener tres valores discretos.
#
# Al pasar el mouse por encima de las barras, deberíamos poder ver el nombre del pokemon.

# %%
df["Stage"] = df["Stage"].astype('object') #hay que hacerlo para asociar correctamente el color discrete sequence
px.bar(df.sort_values("Attack"), x='Name', y='Attack', color='Stage', hover_name='Name',color_discrete_sequence =['red', 'green', 'blue'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 7- Haz un scatter plot en el que se muestre el ataque/defensa de cada pokemon y el tamaño de la redonda sea proporcional a sus HP. Cuando se pase el ratón por encima de cada renonda, debe salir el nombre del pokemon.
# Los colores de las redondas deben corresponder al tipo secundario de pokemon. Para aquellos Pokemons que no tengan tipo secundario, puedes usar el tipo primario.
#
#  Ajusta los ejes adecuadamente.

# %%
px.scatter(df.fillna("Primario"), x="Defense", y="Attack", size="HP",hover_name="Name",color="Type 2")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
