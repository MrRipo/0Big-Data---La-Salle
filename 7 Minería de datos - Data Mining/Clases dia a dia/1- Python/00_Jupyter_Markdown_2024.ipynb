# %% [markdown]
# # Jupyter & Markdown

# %% [markdown]
# - - -

# %% [markdown]
# ## ¿Qué es jupyter?

# %% [markdown]
# Jupyter es una aplicación web de código abierto, desarrollada utilizando lenguaje HTML.
# Permite crear, compartir y editar documentos en los que se puede:
#
# * Ejecutar código
# * Hacer anotaciones
# * Insertar ecuaciones
# * Visualizar resultados
# * Documentar funcionalidades
#
# Esta aplicación está diseñada generalmente para tener una compatibilidad avanzada con Python y Markdown.
# Tambien incluye la posibilidad de exportar documentos hechos con la herramienta a otros formatos.
#
# Generalmente esta herramienta es utilizada para:
#
# * La ejecucion de lenguaje Python
# * La limpieza y transformación de datos científicos
# * La simulación numérica
# * El modelado estadístico

# %% [markdown]
# ### Algunos comandos útiles de jupyter

# %% [markdown]
# * Crear nuevas celdas de código o texto
# * Navegar con las flechas hacia arriba y hacia abajo
# * Convertir el tipo de celda a Markdown o código
# * Cambiar al modo de edición utilizando Intro

# %% [markdown]
# ## ¿Qué es Markdown?

# %% [markdown]
# Markdown también se considera un lenguaje. En este caso, este lenguaje tiene la finalidad de permitir crear contenido escrito, y que en todo momento mantenga un diseño legible. Para simplificar, puedes considerar Markdown como un método de escritura.

# %% [markdown]
# ## Ejemplos de sintaxis de Markdown:

# %% [markdown]
# ### 1 - Estilos de Texto

# %% [raw]
# *Esto es cursiva*

# %% [markdown]
# *Esto es cursiva*

# %% [raw]
# **Esto es negrita**

# %% [markdown]
# **Esto es negrita**

# %% [raw]
# ***Esto es cursiva y negrita***

# %% [markdown]
# ***Esto es cursiva y negrita***

# %% [raw]
# ¿Pueden estar en la misma linea distintos estilos de texto?

# %% [raw]
# Esto es *cursiva* y **Negrita** en la misma linea

# %% [markdown]
# Esto es *cursiva* y **Negrita** en la misma linea

# %% [markdown]
# ### 2 - Párrafos

# %% [markdown]
# Para crear párrafos se deja una línea en blanco.

# %% [raw]
# Hola Mundo!
#
# Hola Mundo!

# %% [markdown]
# Hola Mundo!
#
# Hola Mundo!

# %% [markdown]
# ### 3 - Saltos de línea

# %% [markdown]
# Para crear un salto de línea dentro de un párrafo, se dejan dos espacios al final de la última palabra de esa línea.

# %% [raw]
# Hola(espacio)(espacio)
# Mundo!

# %% [markdown]
# Hola
# Mundo!

# %% [markdown]
# ### 4 - Listas

# %% [raw]
# * Esto es una lista
# * Esto es una lista
# * Esto es una lista

# %% [markdown]
# * Esto es una lista
# * Esto es una lista
# * Esto es una lista

# %% [raw]
# 1. Esto es una lista numerada
# 2. Esto es una lista numerada
# 3. Esto es una lista numerada

# %% [markdown]
# 1. Esto es una lista numerada
# 2. Esto es una lista numerada
# 3. Esto es una lista numerada

# %% [raw]
# ¿Cómo podemos hacer sublistas?

# %% [markdown]
# * Esto es una lista
#     * Esto es una sublista
#     * Esto es una sublista
#     * Esto es una sublista
# * Esto es una lista
# * Esto es una lista

# %% [markdown]
# ### 5 - Cabeceras

# %% [raw]
# # Esto es una cabecera H1

# %% [markdown]
# # Esto es una cabecera H1

# %% [raw]
# ## Esto es una cabecera H2

# %% [markdown]
# ## Esto es una cabecera H2

# %% [raw]
# ### Esto es una cabecera H3

# %% [markdown]
# ### Esto es una cabecera H3

# %% [raw]
# #### Esto es una cabecera H4

# %% [markdown]
# #### Esto es una cabecera H4

# %% [markdown]
# - - -
# Más información:
#
# https://developer.mozilla.org/es/docs/Web/HTML/Elemento/Elementos_t%C3%ADtulos
# - - -

# %% [markdown]
# ### 6 - Enlaces

# %% [raw]
# # Podemos crear enlaces para direcciones URL con título, insertando el título entre corchetes y luego la URL entre paréntesis.

# %% [raw]
# [Título del Link](https://www.wikipedia.org)

# %% [markdown]
# [Título del Link](https://www.wikipedia.org)

# %% [markdown]
# ### 7 - Insertar imagen

# %% [raw]
# ![Título de la imagen](https://upload.wikimedia.org/wikipedia/commons/4/48/Markdown-mark.svg)

# %% [markdown]
# ![Título de la imagen](https://upload.wikimedia.org/wikipedia/commons/4/48/Markdown-mark.svg)

# %% [raw]
# <img src=https://upload.wikimedia.org/wikipedia/commons/4/48/Markdown-mark.svg width="200">

# %% [markdown]
# <img src=https://upload.wikimedia.org/wikipedia/commons/4/48/Markdown-mark.svg width="200">

# %% [markdown]
# ### 8 - Linea de separación

# %% [markdown]
# Para crear líneas horizontales se deben escribir tres guiones preferentemnte separados entre sí.

# %% [raw]
# - - -

# %% [markdown]
# - - -

# %% [markdown]
# ### 9 - Código

# %% [markdown]
# Para línea y multilínea

# %% [raw]
# ``` Esto es una línea de código interpretada por Markdown ```

# %% [markdown]
# ``` Esto es una línea de código interpretada por Markdown ```

# %% [markdown]
# - - -
